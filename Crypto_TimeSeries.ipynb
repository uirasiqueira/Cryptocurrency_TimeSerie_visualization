# %% [markdown]
# <a href="https://colab.research.google.com/github/uirasiqueira/Cryptocurrency_TimeSerie_visualization/blob/main/Crypto_TimeSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cryptocurrency_TimeSeries_visualization

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data exploration

# %% [markdown]
# #### You can find interesting data in Yahoo finance and then download historical of any crypto or stock
# #### https://finance.yahoo.com/

# %%
dfbtc = pd.read_csv('BTC-USD', parse_dates=['Date'], index_col = 'Date') #Bitcoin
dfeth = pd.read_csv('ETH-USD', parse_dates=['Date'], index_col = 'Date') #Ethereum

# %%
dfbtc.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# 2018-01-05  15477.200195  17705.199219  15202.799805  17429.500000
# 2018-01-06  17462.099609  17712.400391  16764.599609  17527.000000
# 2018-01-07  17527.300781  17579.599609  16087.700195  16477.599609
# 2018-01-08  16476.199219  16537.900391  14208.200195  15170.099609
#
#                Adj Close       Volume
# Date
# 2018-01-04  15599.200195  21783199744
# 2018-01-05  17429.500000  23840899072
# 2018-01-06  17527.000000  18314600448
# 2018-01-07  16477.599609  15866000384
# 2018-01-08  15170.099609  18413899776

# %%
dfeth.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-04   961.713013  1045.079956   946.085999   980.921997   980.921997
# 2018-01-05   975.750000  1075.390015   956.325012   997.719971   997.719971
# 2018-01-06   995.153992  1060.709961   994.622009  1041.680054  1041.680054
# 2018-01-07  1043.010010  1153.170044  1043.010010  1153.170044  1153.170044
# 2018-01-08  1158.260010  1266.930054  1016.049988  1148.530029  1148.530029
#
#                 Volume
# Date
# 2018-01-04  6502859776
# 2018-01-05  6683149824
# 2018-01-06  4662219776
# 2018-01-07  5569880064
# 2018-01-08  8450970112

# %%
#### We have to change Date datatype to get easier

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-04', '2018-01-05', '2018-01-06', '2018-01-07',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-13',
#                ...
#                '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-29',
#                '2022-07-30', '2022-07-31', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04'],
#               dtype='datetime64[ns]', name='Date', length=1674, freq=None)

# %%
df.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# 2018-01-05  15477.200195  17705.199219  15202.799805  17429.500000
# 2018-01-06  17462.099609  17712.400391  16764.599609  17527.000000
# 2018-01-07  17527.300781  17579.599609  16087.700195  16477.599609
# 2018-01-08  16476.199219  16537.900391  14208.200195  15170.099609
#
#                Adj Close       Volume
# Date
# 2018-01-04  15599.200195  21783199744
# 2018-01-05  17429.500000  23840899072
# 2018-01-06  17527.000000  18314600448
# 2018-01-07  16477.599609  15866000384
# 2018-01-08  15170.099609  18413899776

# %%
df.iloc[:,1]
# Out:
# Date
# 2018-01-04    15739.700195
# 2018-01-05    17705.199219
# 2018-01-06    17712.400391
# 2018-01-07    17579.599609
# 2018-01-08    16537.900391
#                   ...
# 2022-07-31    24121.642578
# 2022-08-01    23464.787109
# 2022-08-02    23415.041016
# 2022-08-03    23578.650391
# 2022-08-04    23197.019531
# Name: High, Length: 1674, dtype: float64

# %%
dfbtc.index
# Out:
# DatetimeIndex(['2018-01-04', '2018-01-05', '2018-01-06', '2018-01-07',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-13',
#                ...
#                '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-29',
#                '2022-07-30', '2022-07-31', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04'],
#               dtype='datetime64[ns]', name='Date', length=1674, freq=None)

# %%
dfbtc.loc['2020-01'].Close
# Out:
# Date
# 2020-01-01    7200.174316
# 2020-01-02    6985.470215
# 2020-01-03    7344.884277
# 2020-01-04    7410.656738
# 2020-01-05    7411.317383
# 2020-01-06    7769.219238
# 2020-01-07    8163.692383
# 2020-01-08    8079.862793
# 2020-01-09    7879.071289
# 2020-01-10    8166.554199
# 2020-01-11    8037.537598
# 2020-01-12    8192.494141
# 2020-01-13    8144.194336
# 2020-01-14    8827.764648
# 2020-01-15    8807.010742
# 2020-01-16    8723.786133
# 2020-01-17    8929.038086
# 2020-01-18    8942.808594
# 2020-01-19    8706.245117
# 2020-01-20    8657.642578
# 2020-01-21    8745.894531
# 2020-01-22    8680.875977
# 2020-01-23    8406.515625
# 2020-01-24    8445.434570
# 2020-01-25    8367.847656
# 2020-01-26    8596.830078
# 2020-01-27    8909.819336
# 2020-01-28    9358.589844
# 2020-01-29    9316.629883
# 2020-01-30    9508.993164
# 2020-01-31    9350.529297
# Name: Close, dtype: float64

# %% [markdown]
# #### check the mean() of any period

# %%
df.loc['2020-01'].Close.mean()
# Out:
# 8389.270476290323

# %%
df.loc['2020-01-01']
# Out:
# Open         7.194892e+03
# High         7.254331e+03
# Low          7.174944e+03
# Close        7.200174e+03
# Adj Close    7.200174e+03
# Volume       1.856566e+10
# Name: 2020-01-01 00:00:00, dtype: float64

# %% [markdown]
# #### Price range

# %%
df.loc['2020-01':'2022-01']
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# 2020-01-05   7410.451660   7544.497070   7400.535645   7411.317383
# ...                  ...           ...           ...           ...
# 2022-01-27  36841.878906  37148.324219  35629.281250  37138.234375
# 2022-01-28  37128.445313  37952.878906  36211.109375  37784.332031
# 2022-01-29  37780.714844  38576.261719  37406.472656  38138.179688
# 2022-01-30  38151.917969  38266.339844  37437.710938  37917.601563
# 2022-01-31  37920.281250  38647.261719  36733.574219  38483.125000
#
#                Adj Close       Volume
# Date
# 2020-01-01   7200.174316  18565664997
# 2020-01-02   6985.470215  20802083465
# ...

# %% [markdown]
# ### BitCoin

# %%
dfbtc.Close.resample('D').mean().plot() #Mean of each month from Close column
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Ethereum

# %%
dfeth.Close.resample('D').mean().plot() #Mean of each month from Close column
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Bitcoin

# %%
plt.figure(figsize=(18,18))
plt.scatter(x=dfbtc.index, y=df['Volume'])

# %% [markdown]
# ### Ethereum

# %%
plt.figure(figsize=(18,18))
plt.scatter(x=dfeth.index, y=dfeth['Volume'])

# %%
plt.figure(figsize=(18,18))
x1 = dfbtc.index
y1 = dfbtc['Volume']
x2 = dfeth.index
y2 = dfeth['Volume']
plt.plot(x1, y1, label = 'line 1')
plt.plot(x2, y2, label = 'line 2')
plt.show()
